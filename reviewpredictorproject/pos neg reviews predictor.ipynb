# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('googleplaystore.csv')
df1=pd.read_csv("googleplaystore_user_reviews.csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df1.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
for i in df['App'].unique():
    print(i)
# Out:
# Photo Editor & Candy Camera & Grid & ScrapBook
# Coloring book moana
# U Launcher Lite – FREE Live Cool Themes, Hide Apps
# Sketch - Draw & Paint
# Pixel Draw - Number Art Coloring Book
# Paper flowers instructions
# Smoke Effect Photo Maker - Smoke Editor
# Infinite Painter
# Garden Coloring Book
# Kids Paint Free - Drawing Fun
# Text on Photo - Fonteee
# Name Art Photo Editor - Focus n Filters
# Tattoo Name On My Photo Editor
# Mandala Coloring Book
# 3D Color Pixel by Number - Sandbox Art Coloring
# Learn To Draw Kawaii Characters
# Photo Designer - Write your name with shapes
# 350 Diy Room Decor Ideas
# FlipaClip - Cartoon animation
# ibis Paint X
# Logo Maker - Small Business
# Boys Photo Editor - Six Pack & Men's Suit
# Superheroes Wallpapers | 4K Backgrounds
# Mcqueen Coloring pages
# HD Mickey Minnie Wallpapers
# Harley Quinn wallpapers HD
# Colorfit - Drawing & Coloring
# Animated Photo Editor
# Pencil Sketch Drawing
# Easy Realistic Drawing Tutorial
# ...

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid', nan, '0'], dtype=object)

# %%
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated', nan], dtype=object)

# %%
df['Genres'].unique()
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Art & Design;Action & Adventure',
#        'Auto & Vehicles', 'Beauty', 'Books & Reference', 'Business',
#        'Comics', 'Comics;Creativity', 'Communication', 'Dating',
#        'Education;Education', 'Education', 'Education;Creativity',
#        'Education;Music & Video', 'Education;Action & Adventure',
#        'Education;Pretend Play', 'Education;Brain Games', 'Entertainment',
#        'Entertainment;Music & Video', 'Entertainment;Brain Games',
#        'Entertainment;Creativity', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play',
#        'Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
# ...

# %%
df1['App'].unique()
# Out:
# array(['10 Best Foods for You', '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#        '11st', ..., 'Hotwire Hotel & Car Rental App',
#        'Housing-Real Estate & Property', 'Houzz Interior Design Ideas'],
#       dtype=object)

# %%
df1['Translated_Review'].isnull().sum()
# Out:
# 26868

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
np.mean(df['Rating'].value_counts().index)
# Out:
# 3.4900000000000007

# %%
df1.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
df1['Sentiment'].value_counts()
# Out:
# Sentiment
# Positive    23998
# Negative     8271
# Neutral      5163
# Name: count, dtype: int64

# %%
df1['Sentiment'].unique()
# Out:
# array(['Positive', nan, 'Neutral', 'Negative'], dtype=object)

# %%
df['App'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='App'>

# %%
df['Category'].value_counts().head(10).plot(kind='barh')
# Out:
# <Axes: ylabel='Category'>

# %%
df['Size'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Size'>

# %%
df['Content Rating'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Content Rating'>

# %%
df1['App'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='App'>

# %%
df1[df1['App']=='10 Best Foods for You']
# Out:
#                        App                                  Translated_Review  \
# 0    10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1    10 Best Foods for You    This help eating healthy exercise regular basis
# 2    10 Best Foods for You                                                NaN
# 3    10 Best Foods for You         Works great especially going grocery store
# 4    10 Best Foods for You                                       Best idea us
# ..                     ...                                                ...
# 195  10 Best Foods for You  Boring. I thought actually just texts that's i...
# 196  10 Best Foods for You  Love app. It gives way good idea I buying stor...
# 197  10 Best Foods for You  Great Its really best unique provides detailed...
# 198  10 Best Foods for You       Nothing special! Could find anything useful!
# 199  10 Best Foods for You                                  Its ok I love ok.
#
# ...

# %%
df[df['App']=='10 Best Foods for You']
# Out:
#                         App            Category  Rating Reviews  Size  \
# 1393  10 Best Foods for You  HEALTH_AND_FITNESS     4.0    2490  3.8M
# 1407  10 Best Foods for You  HEALTH_AND_FITNESS     4.0    2490  3.8M
#
#       Installs  Type Price Content Rating            Genres  \
# 1393  500,000+  Free     0   Everyone 10+  Health & Fitness
# 1407  500,000+  Free     0   Everyone 10+  Health & Fitness
#
#            Last Updated Current Ver   Android Ver
# 1393  February 17, 2017         1.9  2.3.3 and up
# 1407  February 17, 2017         1.9  2.3.3 and up

# %%
new_df=df.merge(df1,on='App',how='outer')

# %%
new_df
# Out:
#                                                    App        Category  \
# 0       Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                  Coloring book moana  ART_AND_DESIGN
# 2                                  Coloring book moana  ART_AND_DESIGN
# 3                                  Coloring book moana  ART_AND_DESIGN
# 4                                  Coloring book moana  ART_AND_DESIGN
# ...                                                ...             ...
# 134705                  Home Street – Home Design Game             NaN
# 134706                  Home Street – Home Design Game             NaN
# 134707                  Home Street – Home Design Game             NaN
# 134708                  Home Street – Home Design Game             NaN
# 134709                  Home Street – Home Design Game             NaN
#
#         Rating Reviews Size  Installs  Type Price Content Rating  \
# ...

# %%
new_df['Category'].value_counts()
# Out:
# Category
# GAME                   29311
# FAMILY                 11784
# SPORTS                  9154
# HEALTH_AND_FITNESS      6835
# PRODUCTIVITY            6129
# PHOTOGRAPHY             5924
# DATING                  5910
# COMMUNICATION           4780
# TRAVEL_AND_LOCAL        4574
# SHOPPING                4530
# ENTERTAINMENT           4357
# TOOLS                   4020
# MEDICAL                 3790
# EDUCATION               3594
# BUSINESS                3577
# NEWS_AND_MAGAZINES      3441
# FINANCE                 3389
# PERSONALIZATION         2540
# LIFESTYLE               2449
# SOCIAL                  2065
# BOOKS_AND_REFERENCE     1576
# FOOD_AND_DRINK          1571
# HOUSE_AND_HOME          1418
# AUTO_AND_VEHICLES        679
# VIDEO_PLAYERS            664
# BEAUTY                   636
# ART_AND_DESIGN           601
# LIBRARIES_AND_DEMO       592
# MAPS_AND_NAVIGATION      566
# PARENTING                489
# WEATHER                  355
# ...

# %%
new_df.isnull().sum()
# Out:
# App                           0
# Category                   2739
# Rating                     4252
# Reviews                    2739
# Size                       2739
# Installs                   2739
# Type                       2740
# Price                      2739
# Content Rating             2740
# Genres                     2739
# Last Updated               2739
# Current Ver                2747
# Android Ver                2742
# Translated_Review         60607
# Sentiment                 60597
# Sentiment_Polarity        60597
# Sentiment_Subjectivity    60597
# dtype: int64

# %%
new_df.dropna(inplace=True)

# %%
new_df.isnull().sum()
# Out:
# App                       0
# Category                  0
# Rating                    0
# Reviews                   0
# Size                      0
# Installs                  0
# Type                      0
# Price                     0
# Content Rating            0
# Genres                    0
# Last Updated              0
# Current Ver               0
# Android Ver               0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression,RidgeClassifier,LogisticRegression
from sklearn.neighbors import  KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,ExtraTreesClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import VotingClassifier,StackingClassifier
from sklearn.preprocessing import StandardScaler
from catboost import CatBoostClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder

# %%
X=new_df.drop('Sentiment',axis=1)
y=new_df['Sentiment']

# %%
le=LabelEncoder()

# %%
y
# Out:
# 1         Negative
# 2         Negative
# 3          Neutral
# 5         Positive
# 6         Negative
#             ...
# 131004    Positive
# 131010    Positive
# 131017    Positive
# 131018     Neutral
# 131019    Positive
# Name: Sentiment, Length: 72566, dtype: object

# %%
y_new=le.fit_transform(y)

# %%
y_new
# Out:
# array([0, 0, 1, ..., 2, 1, 2])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y_new,test_size=0.2,random_state=42)

# %%
from sklearn.pipeline import Pipeline

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf_vectorizer = TfidfVectorizer(max_features=5000)  
tfidf_vectorizer
# Out:
# TfidfVectorizer(max_features=5000)

# %%
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train['Translated_Review'])
X_test_tfidf = tfidf_vectorizer.transform(X_test['Translated_Review'])

# %%
X_train1=X_train_tfidf.toarray()
X_test1=X_test_tfidf.toarray()

# %%
ETR=ExtraTreesClassifier(n_estimators=100,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15,bootstrap=True)
SVR=SVC(kernel='rbf',C=10000)
GDR=GradientBoostingClassifier()
XGBR=XGBClassifier(n_estimators=50,max_depth=5,learning_rate=0.5)
ADBR=AdaBoostClassifier(n_estimators=15,learning_rate=0.001)

# %%
GUNB=GaussianNB()
ridge=RidgeClassifier(alpha=25)
MNB=MultinomialNB(alpha=0.1)
LoR=LogisticRegression()
dt=DecisionTreeClassifier(max_depth=5)
KNN=KNeighborsClassifier(n_neighbors=3)
RFF=RandomForestClassifier(n_estimators=5000,
    random_state=4,max_samples=0.9,
    max_features=1,
    max_depth=25)

# %%
CBC=CatBoostClassifier(n_estimators=1500, learning_rate=0.1,
    l2_leaf_reg=3,
    depth=6,
    auto_class_weights="Balanced",
    eval_metric="AUC",
    early_stopping_rounds=10,
    verbose=100,
    random_seed=42)

# %%
rfv=RandomForestClassifier(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=19)
gbdtv=GradientBoostingClassifier(n_estimators=100,max_features=0.5)
xgbv=XGBClassifier(n_estimators=25,learning_rate=0.3,max_depth=5)
etv=ExtraTreesClassifier(n_estimators=100,random_state=3,max_samples=0.5,max_features=0.75,max_depth=10,bootstrap=True)
VR=VotingClassifier([('rfv',rfv),('gbdtv',gbdtv),('xgbv',xgbv),('etv',etv)],weights=[5,1,1,1])

# %%
#GUNB.fit(X_train1,y_train)
#y_pred = GUNB.predict(X_test1)
#print("Accuracy_score of GUNB ",accuracy_score(y_test,y_pred))

# %%
#ridge.fit(X_train1,y_train)
#y_pred = ridge.predict(X_test1)
#print("Accuracy_score of ridge",accuracy_score(y_test,y_pred))

# %%
#MNB.fit(X_train1,y_train)
#y_pred = MNB.predict(X_test1)
#print("Accuracy_score of MNB",accuracy_score(y_test,y_pred))

# %%
LoR.fit(X_train1,y_train)
y_pred1 = LoR.predict(X_test1)
print("Accuracy_score of LoR",accuracy_score(y_test,y_pred1))
# Out:
# C:\Users\Aryan raina\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy_score of LoR 0.9506683202425245

# %%
#dt.fit(X_train1,y_train)
#y_pred = dt.predict(X_test1)
#print("Accuracy_score of dt",accuracy_score(y_test,y_pred))

# %%
#KNN.fit(X_train1,y_train)
#y_pred = KNN.predict(X_test1)
#print("Accuracy_score of KNN",accuracy_score(y_test,y_pred))

# %%
#RFF.fit(X_train1,y_train)
#y_pred = RFF.predict(X_test1)
#print("Accuracy_score of RFF",accuracy_score(y_test,y_pred))

# %%
#ETR.fit(X_train1,y_train)
#y_pred = ETR.predict(X_test1)
#print("Accuracy_score of ETR",accuracy_score(y_test,y_pred))

# %%
#GDR.fit(X_train1,y_train)
#y_pred = GDR.predict(X_test1)
#print("Accuracy_score of GDR",accuracy_score(y_test,y_pred))

# %%
#CBC.fit(X_train1,y_train)
#y_pred = CBC.predict(X_test1)
#print("Accuracy_score of CBC",accuracy_score(y_test,y_pred))

# %%
#XGBR.fit(X_train1,y_train)
#y_pred2 = XGBR.predict(X_test1)
#print("Accuracy_score of XGBR",accuracy_score(y_test,y_pred))

# %%
#ADBR.fit(X_train1,y_train)
#y_pred = ADBR.predict(X_test1)
#print("Accuracy_score of ADBR",accuracy_score(y_test,y_pred))

# %%
#SVR.fit(X_train1,y_train)
#y_pred = SVR.predict(X_test1)
#print("Accuracy_score of SVR",accuracy_score(y_test,y_pred))

# %%
estimators=[('rfs',RandomForestClassifier(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=19)),
   ('gbdts',GradientBoostingClassifier(n_estimators=100,max_features=0.5)),
('xgbs',XGBClassifier(n_estimators=25,learning_rate=0.3,max_depth=5))]
SR=StackingClassifier(estimators=estimators,final_estimator=RidgeClassifier(alpha=100))

# %%
#VR.fit(X_train1,y_train)
#y_pred=VR.predict(X_test1)
#print("Accuracy_score",accuracy_score(y_test,y_pred))

# %%
#sns.heatmap(confusion_matrix(y_test,y_pred))

# %%
#SR.fit(X_train1,y_train)
#y_pred=SR.predict(X_test1)
#print("Accuracy_score",accuracy_score(y_test,y_pred))

# %%
#sns.heatmap(confusion_matrix(y_test,y_pred))

# %%
sns.heatmap(confusion_matrix(y_test,y_pred1))
# Out:
# <Axes: >

# %%
from sklearn.metrics import classification_report

# %%
report = classification_report(y_test, y_pred1)

# %%
report
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.94      0.91      0.93      3630\n           1       0.93      0.89      0.91      1589\n           2       0.96      0.98      0.97      9295\n\n    accuracy                           0.95     14514\n   macro avg       0.94      0.93      0.93     14514\nweighted avg       0.95      0.95      0.95     14514\n'

# %%
pipe=Pipeline(
    steps=[
        ('tfidf',TfidfVectorizer(max_features=5000,lowercase=False)),
        ('LoR',LogisticRegression())
    ]
)

# %%
pipe.fit(X_train['Translated_Review'],y_train)
# Out:
# C:\Users\Aryan raina\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('tfidf', TfidfVectorizer(lowercase=False, max_features=5000)),
#                 ('LoR', LogisticRegression())])

# %%
your_review_text = "I loved the product, it's good!"

# %%
review_list = [your_review_text]

# %%
pipe.predict(review_list)[0]
# Out:
# 2

# %%
y_pred2=pipe.predict(X_test['Translated_Review'])

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9506683202425245

# %%
import pickle

# %%
pickle.dump(pipe,open('pipeReviews.pkl','wb'))

# %%
new_df
# Out:
#                                  App        Category  Rating Reviews  \
# 1                Coloring book moana  ART_AND_DESIGN     3.9     967
# 2                Coloring book moana  ART_AND_DESIGN     3.9     967
# 3                Coloring book moana  ART_AND_DESIGN     3.9     967
# 5                Coloring book moana  ART_AND_DESIGN     3.9     967
# 6                Coloring book moana  ART_AND_DESIGN     3.9     967
# ...                              ...             ...     ...     ...
# 131004  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 131010  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 131017  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 131018  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 131019  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
#
#                       Size     Installs  Type Price Content Rating  \
# 1                      14M     500,000+  Free     0       Everyone
# ...

# %%
pickle.dump(new_df,open('new_dfReview.pkl','wb'))

# %%
new_df['Translated_Review'].iloc[:50]
# Out:
# 1     A kid's excessive ads. The types ads allowed a...
# 2                                            It bad >:(
# 3                                                  like
# 5                              I love colors inspyering
# 6                                                I hate
# 8                                              omgggggg
# 9                                              It cute.
# 10                                               I love
# 11                                                 Love
# 12                                 I love enjoyable fun
# 14                          It horrible even zoom color
# 15                                               I sure
# 16                                      It stoepet game
# 17                                         Too many ads
# 18                                   It missing filling
# 19                                           Good great
# 20                                              It's ok
# ...
